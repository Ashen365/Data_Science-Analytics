# %%
import pandas as pd 
from apyori import apriori #apyori=

# %%
movie_data = pd.read_csv("movie_dataset.csv",header=None)

# %%
movie_data
# Out:
#                    0           1                   2   \
# 0        The Revenant    13 Hours              Allied
# 1              Beirut     Martian             Get Out
# 2            Deadpool         NaN                 NaN
# 3               X-Men      Allied                 NaN
# 4       Ninja Turtles       Moana  Ghost in the Shell
# ...               ...         ...                 ...
# 7496         Big Sick      Looper                Hulk
# 7497           Beirut      Intern             Get Out
# 7498  Captain America         NaN                 NaN
# 7499    Green Lantern   John Wick                 NaN
# 7500          Get Out  Inside Out       I Feel Pretty
#
#                              3          4          5       6   \
# 0                      Zootopia     Jigsaw   Achorman  Grinch
# 1                           NaN        NaN        NaN     NaN
# 2                           NaN        NaN        NaN     NaN
# 3                           NaN        NaN        NaN     NaN
# ...

# %%
display(movie_data.head())
# Out:
#               0         1                   2                          3   \
# 0   The Revenant  13 Hours              Allied                   Zootopia
# 1         Beirut   Martian             Get Out                        NaN
# 2       Deadpool       NaN                 NaN                        NaN
# 3          X-Men    Allied                 NaN                        NaN
# 4  Ninja Turtles     Moana  Ghost in the Shell  Ralph Breaks the Internet
#
#           4         5       6                 7             8          9   \
# 0     Jigsaw  Achorman  Grinch  Fast and Furious  Ghostbusters  Wolverine
# 1        NaN       NaN     NaN               NaN           NaN        NaN
# 2        NaN       NaN     NaN               NaN           NaN        NaN
# 3        NaN       NaN     NaN               NaN           NaN        NaN
# 4  John Wick       NaN     NaN               NaN           NaN        NaN
#
#         10         11          12                 13             14  \
# ...

# %%
movie_data.shape
# Out:
# (7501, 20)

# %%
records = [] 
for i in range(0, 7501): 
    records.append([str(movie_data.values[i, j]) for j in range(0, 20)])

# %%
records
# Out:
# [['The Revenant',
#   '13 Hours',
#   'Allied',
#   'Zootopia',
#   'Jigsaw',
#   'Achorman',
#   'Grinch',
#   'Fast and Furious',
#   'Ghostbusters',
#   'Wolverine',
#   'Mad Max',
#   'John Wick',
#   'La La Land',
#   'The Good Dunosaur',
#   'Ninja Turtles',
#   'The Good Dunosaur Bad Moms',
#   '2 Guns',
#   'Inside Out',
#   'Valerian',
#   'Spiderman 3'],
#  ['Beirut',
#   'Martian',
#   'Get Out',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['Deadpool',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['X-Men',
#   'Allied',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %%
association_rules = apriori(records, min_support=0.01, min_confidence=0.5,min_length=2) 
#list of list

# %%
association_results = list(association_rules)

# %%
association_results
# Out:
# [RelationRecord(items=frozenset({'nan'}), support=0.9998666844420744, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.9998666844420744, lift=1.0)]),
#  RelationRecord(items=frozenset({'nan', '13 Hours'}), support=0.020263964804692707, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13 Hours'}), items_add=frozenset({'nan'}), confidence=0.9934640522875817, lift=0.9935965141612201)]),
#  RelationRecord(items=frozenset({'nan', 'Allied'}), support=0.03319557392347687, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Allied'}), items_add=frozenset({'nan'}), confidence=0.996, lift=0.9961328)]),
#  RelationRecord(items=frozenset({'nan', 'Ant Man'}), support=0.010798560191974404, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ant Man'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
# ...
